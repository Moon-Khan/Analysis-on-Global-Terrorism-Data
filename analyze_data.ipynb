# %% [markdown]
# ### Importing Data and libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv('terrorism.csv',encoding='latin1')
df.head()
# Out:
# C:\Users\HF\AppData\Local\Temp\ipykernel_12656\4228112155.py:5: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('terrorism.csv',encoding='latin1')
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# ...

# %% [markdown]
# ### Data Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df.columns.to_list()
# Out:
# ['eventid',
#  'iyear',
#  'imonth',
#  'iday',
#  'approxdate',
#  'extended',
#  'resolution',
#  'country',
#  'country_txt',
#  'region',
#  'region_txt',
#  'provstate',
#  'city',
#  'latitude',
#  'longitude',
#  'specificity',
#  'vicinity',
#  'location',
#  'summary',
#  'crit1',
#  'crit2',
#  'crit3',
#  'doubtterr',
#  'alternative',
#  'alternative_txt',
#  'multiple',
#  'success',
#  'suicide',
#  'attacktype1',
#  'attacktype1_txt',
#  'attacktype2',
#  'attacktype2_txt',
#  'attacktype3',
#  'attacktype3_txt',
#  'targtype1',
#  'targtype1_txt',
#  'targsubtype1',
#  'targsubtype1_txt',
#  'corp1',
#  'target1',
#  'natlty1',
#  'natlty1_txt',
#  'targtype2',
#  'targtype2_txt',
#  'targsubtype2',
#  'targsubtype2_txt',
#  'corp2',
#  'target2',
#  'natlty2',
#  'natlty2_txt',
#  'targtype3',
#  'targtype3_txt',
#  'targsubtype3',
#  'targsubtype3_txt',
#  'corp3',
#  'target3',
#  'natlty3',
#  'natlty3_txt',
#  'gname',
#  'gsubname',
#  'gname2',
#  'gsubname2',
# ...

# %% [markdown]
# ### Renaming Columns

# %%
df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'state',
                       'region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed',
                       'nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type',
                       'weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)
df
# Out:
#              eventid  Year  Month  Day approxdate  extended resolution  \
# 0       197000000001  1970      7    2        NaN         0        NaN
# 1       197000000002  1970      0    0        NaN         0        NaN
# 2       197001000001  1970      1    0        NaN         0        NaN
# 3       197001000002  1970      1    0        NaN         0        NaN
# 4       197001000003  1970      1    0        NaN         0        NaN
# ...              ...   ...    ...  ...        ...       ...        ...
# 181686  201712310022  2017     12   31        NaN         0        NaN
# 181687  201712310029  2017     12   31        NaN         0        NaN
# 181688  201712310030  2017     12   31        NaN         0        NaN
# 181689  201712310031  2017     12   31        NaN         0        NaN
# 181690  201712310032  2017     12   31        NaN         0        NaN
#
#         country             Country  region  ... addnotes  \
# ...

# %%
df=df[['Year','Month','Day','Country','state','Region','city','latitude','longitude','AttackType','Killed',
               'Wounded','Target','Summary','Group','Target_type','Weapon_type','Motive']]
df
# Out:
#         Year  Month  Day             Country            state  \
# 0       1970      7    2  Dominican Republic              NaN
# 1       1970      0    0              Mexico          Federal
# 2       1970      1    0         Philippines           Tarlac
# 3       1970      1    0              Greece           Attica
# 4       1970      1    0               Japan          Fukouka
# ...      ...    ...  ...                 ...              ...
# 181686  2017     12   31             Somalia  Middle Shebelle
# 181687  2017     12   31               Syria         Lattakia
# 181688  2017     12   31         Philippines      Maguindanao
# 181689  2017     12   31               India          Manipur
# 181690  2017     12   31         Philippines      Maguindanao
#
#                              Region           city   latitude   longitude  \
# 0       Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# ...

# %% [markdown]
# ### Data Preprocessing and Cleaning

# %%
df.isnull().sum()
# Out:
# Year                0
# Month               0
# Day                 0
# Country             0
# state             421
# Region              0
# city              435
# latitude         4556
# longitude        4557
# AttackType          0
# Killed          10313
# Wounded         16311
# Target            638
# Summary         66129
# Group               0
# Target_type         0
# Weapon_type         0
# Motive         131130
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 18 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Year         181691 non-null  int64
#  1   Month        181691 non-null  int64
#  2   Day          181691 non-null  int64
#  3   Country      181691 non-null  object
#  4   state        181270 non-null  object
#  5   Region       181691 non-null  object
#  6   city         181256 non-null  object
#  7   latitude     177135 non-null  float64
#  8   longitude    177134 non-null  float64
#  9   AttackType   181691 non-null  object
#  10  Killed       171378 non-null  float64
#  11  Wounded      165380 non-null  float64
#  12  Target       181053 non-null  object
#  13  Summary      115562 non-null  object
#  14  Group        181691 non-null  object
#  15  Target_type  181691 non-null  object
#  16  Weapon_type  181691 non-null  object
#  17  Motive       50561 non-null   object
# ...

# %%
print(df.state.isnull().sum())
print(df.city.isnull().sum())
print(df.Killed.isnull().sum())
print(df.Wounded.isnull().sum())
print(df.Target.isnull().sum())
# Out:
# 421
# 435
# 10313
# 16311
# 638

# %%
df.dropna(subset=['state', 'city', 'Killed', 'Wounded', 'Target'], inplace=True)
# Out:
# C:\Users\HF\AppData\Local\Temp\ipykernel_12656\830412791.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=['state', 'city', 'Killed', 'Wounded', 'Target'], inplace=True)

# %%
print(df.state.isnull().sum())
print(df.city.isnull().sum())
print(df.Killed.isnull().sum())
print(df.Wounded.isnull().sum())
print(df.Target.isnull().sum())
# Out:
# 0
# 0
# 0
# 0
# 0

# %% [markdown]
# ### Data Analysis

# %%
print("Most attacks in a Country:",df['Country'].value_counts().idxmax())
print("Most attacks in a Year:",df['Year'].value_counts().idxmax())
print("Most attacks in a Month:",df['Month'].value_counts().idxmax())
print("Most attacks in a Day:",df['Day'].value_counts().idxmax())
print("Most attacks in a Region:",df['Region'].value_counts().idxmax())
print("Most attacks in a Group:",df['Group'].value_counts().index[1])
# Out:
# Most attacks in a Country: Iraq
# Most attacks in a Year: 2014
# Most attacks in a Month: 5
# Most attacks in a Day: 15
# Most attacks in a Region: Middle East & North Africa
# Most attacks in a Group: Taliban

# %% [markdown]
# ### Data Analysis through Visualization

# %% [markdown]
# #### Number of Attacks in a Year

# %%
years = df['Year'].unique()
no_of_attack = df['Year'].value_counts().sort_index()

plt.figure(figsize=(10, 6))
sns.barplot(x=years, y=no_of_attack, palette='viridis')
plt.title('Number of Attacks in a Year')
plt.xticks(rotation = 90)
plt.xlabel('Years')
plt.ylabel('No of Attacks')
plt.show()

# %% [markdown]
# #### No of Attacks in Each Year by Region

# %%
no_of_attacks_by_region = df.groupby(['Year', 'Region']).size().unstack(fill_value=0)

plt.figure(figsize=(14, 8))
sns.heatmap(no_of_attacks_by_region, cmap='viridis', annot=True, fmt='d', linewidths=.5, cbar_kws={'label': 'Number of Attacks'})
plt.title('Number of Attacks in Each Year by Region')
plt.xlabel('Region')
plt.ylabel('Year')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Top 10 Worst Terror Attacks on Countries (2001 and later)

# %%
df['Casualties'] = df['Killed'] + df['Wounded']

filtered_df = df[df['Year'] > 2000]

year_country_casualties = filtered_df.groupby(['Year', 'Country'])['Casualties'].sum().reset_index()

top_10_attacks = year_country_casualties.groupby('Year').apply(lambda x: x.nlargest(10, 'Casualties')).reset_index(drop=True)

heatmap_data = top_10_attacks.pivot(index='Year', columns='Country', values='Casualties').fillna(0)

plt.figure(figsize=(14, 8))
sns.heatmap(heatmap_data, cmap='viridis',  fmt='g', linewidths=.5, cbar_kws={'label': 'Number of Casualties'})
plt.title('Top 10 Worst Terror Attacks on Countries (2001 and later)')
plt.xlabel('Country')
plt.ylabel('Year')
plt.yticks(rotation=0)
plt.show()
# Out:
# C:\Users\HF\AppData\Local\Temp\ipykernel_12656\4102612290.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Casualties'] = df['Killed'] + df['Wounded']

# %% [markdown]
# ### Top 10 Most Affected Countries by Terror Attacks

# %%
df['Casualties'] = df['Killed'] + df['Wounded']

country_casualties = df.groupby('Country')['Casualties'].sum().reset_index()

sorted_countries = country_casualties.sort_values(by='Casualties', ascending=False)

top_10_countries = sorted_countries.head(10)

# Plotting the bar plot
plt.figure(figsize=(12, 6))
plt.bar(top_10_countries['Country'], top_10_countries['Casualties'], color='blue', alpha=0.7)
plt.title('Top 10 Most Affected Countries by Terror Attacks')
plt.xlabel('Country')
plt.ylabel('Number of Casualties')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\HF\AppData\Local\Temp\ipykernel_12656\4045387046.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Casualties'] = df['Killed'] + df['Wounded']

# %% [markdown]
# ### Distribution of Attack Types in Top 10 Most Affected Countries

# %%
df['Casualties'] = df['Killed'] + df['Wounded']

country_attack_types = df.groupby(['Country', 'AttackType']).size().unstack(fill_value=0)

top_10_countries = df.groupby('Country')['Casualties'].sum().nlargest(10).index
country_attack_types_top_10 = country_attack_types.loc[top_10_countries]

plt.figure(figsize=(14, 8))
country_attack_types_top_10.plot(kind='bar', stacked=True, colormap='viridis')
plt.title('Distribution of Attack Types in Top 10 Most Affected Countries')
plt.xlabel('Country')
plt.ylabel('Number of Attacks')
plt.legend(title='Attack Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
# Out:
# C:\Users\HF\AppData\Local\Temp\ipykernel_12656\2619017435.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Casualties'] = df['Killed'] + df['Wounded']

# %% [markdown]
# ### Top 10 Countries with the Highest Casualties by Region

# %%
df['Casualties'] = df['Killed'] + df['Wounded']

country_casualties = df.groupby(['Country', 'Region'])['Casualties'].sum().reset_index()

top_countries = country_casualties.groupby('Country')['Casualties'].sum().nlargest(10).index
top_countries_data = country_casualties[country_casualties['Country'].isin(top_countries)]

plt.figure(figsize=(14, 8))
sns.barplot(x='Casualties', y='Country', hue='Region', data=top_countries_data, palette='viridis')
plt.title('Top 10 Countries with the Highest Casualties by Region')
plt.xlabel('Number of Casualties')
plt.ylabel('Country')
plt.legend(title='Region', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
# Out:
# C:\Users\HF\AppData\Local\Temp\ipykernel_12656\3999211642.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Casualties'] = df['Killed'] + df['Wounded']

# %% [markdown]
# ### Distribution of Attack Targets

# %%
df['Casualties'] = df['Killed'] + df['Wounded']

target_types = df.groupby('Target_type')['Casualties'].sum().reset_index()

plt.figure(figsize=(14, 8))
sns.barplot(x='Casualties', y='Target_type', data=target_types, palette='viridis')
plt.title('Distribution of Attack Targets')
plt.xlabel('Number of Casualties')
plt.ylabel('Target Type')
plt.show()
# Out:
# C:\Users\HF\AppData\Local\Temp\ipykernel_12656\1756642309.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Casualties'] = df['Killed'] + df['Wounded']

# %% [markdown]
# ### Distribution of Weapons Used in Attacks

# %%
df['Casualties'] = df['Killed'] + df['Wounded']

weapon_types = df.groupby('Weapon_type')['Casualties'].sum().reset_index()

plt.figure(figsize=(14, 8))
sns.barplot(x='Casualties', y='Weapon_type', data=weapon_types, palette='viridis')
plt.title('Distribution of Weapons Used in Attacks')
plt.xlabel('Number of Casualties')
plt.ylabel('Weapon Type')
plt.show()
# Out:
# C:\Users\HF\AppData\Local\Temp\ipykernel_12656\2305536580.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Casualties'] = df['Killed'] + df['Wounded']
